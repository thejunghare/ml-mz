# %% [markdown]
# <a href="https://colab.research.google.com/github/thejunghare/ml-mz/blob/main/linearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/content/1_linear_regression.csv')

# %%
# df.head()
# df.tail()
print(df)
# Out:
#    hours  marks
# 0      1   35.0
# 1      2   40.0
# 2      3   50.0
# 3      4   55.0
# 4      5   65.0
# 5      6    NaN
# 6      7   80.0
# 7      8   85.0

# %%
df.isnull().sum()
# Out:
# hours    0
# marks    1
# dtype: int64

# %%
marks_mean = np.mean(df['marks'])
print(marks_mean)
# Out:
# 58.57142857142857

# %%
df = df.fillna(marks_mean)

# %%
print(df)
# Out:
#    hours      marks
# 0      1  35.000000
# 1      2  40.000000
# 2      3  50.000000
# 3      4  55.000000
# 4      5  65.000000
# 5      6  58.571429
# 6      7  80.000000
# 7      8  85.000000

# %%
x=df.hours
y=df.marks
print(np.shape(y))
print(np.shape(x))
x= np.reshape(x,[1,8])
y = np.reshape(y,[1,8])
# Out:
# (8,)
# (8,)

# %%
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[1,2,3,4,5,6,7,8]])
# Out:
# array([[35.        , 40.        , 50.        , 55.        , 65.        ,
#         58.57142857, 80.        , 85.        ]])

# %%
df.hours[9] = 9
# Out:
# /tmp/ipykernel_2881/3236985706.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.hours[9] = 9
# /tmp/ipykernel_2881/3236985706.py:1: SettingWithCopyWarning:
# ...

# %%
print(df.tail())
# Out:
#    hours      marks
# 3      4  55.000000
# 4      5  65.000000
# 5      6  58.571429
# 6      7  80.000000
# 7      8  85.000000
