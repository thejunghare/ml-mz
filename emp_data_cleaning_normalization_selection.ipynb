# %% [markdown]
# <a href="https://colab.research.google.com/github/thejunghare/ml-mz/blob/main/emp_data_cleaning_normalization_selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# data preprocessin
# drop, fill
#  normalization -

# %%
import pandas as pd
import numpy as  np
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import KNNImputer

# %%
df = pd.read_excel('/content/EMP_DATA.xlsx')

# %%
print(df.head())
# Out:
#    EmployeeID   Age   Salary  Experience Department       City  \
# 0           1  28.0  28278.0         3.0         HR       Pune
# 1           2  58.0  80302.0        37.0         IT     Mumbai
# 2           3   NaN      NaN         NaN         HR  Bengaluru
# 3           4  48.0  69597.0        23.0         HR       Pune
# 4           5  26.0  74797.0         4.0        NaN      Delhi
#
#    PerformanceScore  Attendance  Gender
# 0               1.6        71.0    Male
# 1               1.9        97.0    Male
# 2               3.4        65.0    Male
# 3               4.8        86.0    Male
# 4               3.4        67.0  Female

# %%
# find all null values
print(df.isnull().sum())
# Out:
# EmployeeID           0
# Age                 30
# Salary              31
# Experience          31
# Department          15
# City                21
# PerformanceScore    30
# Attendance          37
# Gender              16
# dtype: int64

# %%
print(df.duplicated().sum())

new_df = df.drop_duplicates()

mean_age = np.mean(new_df['Age'])

# pd.fillna(new_df['Age'], mean_age)
df.Age.fillna(mean_age)
imputer = KNNImputer(n_neighbors=2)
# new_exp = new_df['Experience'].reshape(0, 1)
imputer.fit_transform(new_df)
# Out:
# 5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_489/2505147777.py in <cell line: 0>()
#       9 imputer = KNNImputer(n_neighbors=2)
#      10 # new_exp = new_df['Experience'].reshape(0, 1)
# ---> 11 imputer.fit_transform(new_df)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# ...
