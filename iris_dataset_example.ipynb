# %% [markdown]
# <a href="https://colab.research.google.com/github/thejunghare/ml-mz/blob/main/iris_dataset_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import pandas as pd
from pandas.plotting import scatter_matrix
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

iris_dataset = load_iris()
knn = KNeighborsClassifier(n_neighbors=1)

# %%
print(iris_dataset.feature_names) # att names
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
print(iris_dataset.keys()) # not necessary
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
print(iris_dataset['target'].shape) # 150 flowers
# Out:
# (150,)

# %%
x_train, x_test, y_train, y_test = train_test_split(iris_dataset['data'], iris_dataset['target'], random_state = 0)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (112, 4) (112,)
# (38, 4) (38,)

# %%
iris_dataframe = pd.DataFrame(x_train, columns=iris_dataset.feature_names)
grr = scatter_matrix(iris_dataframe, c=y_train, figsize=(15, 15))

# %%
knn.fit(x_train, y_train) # learn throw 112 flowers
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
x_new = np.array([[5,2.9,1,0.2]])
# print(x_new.shape) # not necessary

# %%
prediction = knn.predict(x_new)
print(prediction)
print(iris_dataset['target_names'])
# Out:
# [0]
# ['setosa' 'versicolor' 'virginica']

# %%
y_pred = knn.predict(x_test)

print(y_pred) # print all prediction for x test i.e 38 flowers

print(np.mean(y_pred == y_test)) #mean

print(knn.score(x_test, y_test))# accuray

wrong = np.where(y_pred != y_test)[0]
print("Index:", wrong)
# Out:
# [2 1 0 2 0 2 0 1 1 1 2 1 1 1 1 0 1 1 0 0 2 1 0 0 2 0 0 1 1 0 2 1 0 2 2 1 0
#  2]
# 0.9736842105263158
# 0.9736842105263158
# Index: [37]
